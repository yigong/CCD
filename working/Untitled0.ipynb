# %%
import numpy as np

# %%
a=np.random.rand(10,20)
x_range=np.arange(10)
y_range=np.arange(20)

a_tmp=a[x_range<5,:]
b=a_tmp[:,np.in1d(y_range,[3,4,8])]

# %%
a_tmp
# Out:
# array([[ 0.42466842,  0.17858814,  0.95052206,  0.29257418,  0.27951906,
#          0.53932713,  0.36109882,  0.21199139,  0.41794491,  0.36138992,
#          0.78878789,  0.51788348,  0.49077205,  0.59629934,  0.14282441,
#          0.83317744,  0.72760133,  0.09578695,  0.52077795,  0.43159694],
#        [ 0.26059913,  0.40382856,  0.36030241,  0.13477795,  0.30730216,
#          0.58559371,  0.83566897,  0.63700951,  0.46976062,  0.37939981,
#          0.29894375,  0.86224121,  0.31267394,  0.47585936,  0.69551223,
#          0.60600086,  0.17067149,  0.35268418,  0.69671655,  0.08034633],
#        [ 0.7250669 ,  0.28335321,  0.01829162,  0.79128232,  0.52249408,
#          0.06161155,  0.95098138,  0.47645236,  0.85116241,  0.08639315,
#          0.26552658,  0.81573521,  0.07511753,  0.26760357,  0.648578  ,
#          0.56662787,  0.40393701,  0.07486842,  0.75098302,  0.3708467 ],
#        [ 0.37815751,  0.52829222,  0.85025629,  0.53594785,  0.93974593,
# ...
